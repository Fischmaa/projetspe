# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('trainRandom.csv')

# %%
data=data.drop('Unnamed: 0',1)
data=data.sort_values("date_time")

# %%
data.head()
# Out:
#                  date_time  site_name  posa_continent  user_location_country  \
# 62211  2013-01-07 01:35:53         24               2                      3
# 97575  2013-01-07 01:40:20          2               3                     48
# 1513   2013-01-07 02:47:27          2               3                     66
# 71814  2013-01-07 03:31:11          2               3                    154
# 75459  2013-01-07 03:59:19         11               3                    205
#
#        user_location_region  user_location_city  orig_destination_distance  \
# 62211                    50                5703                        NaN
# 97575                   424                5957                        NaN
# 1513                    226               25300                   720.6525
# 71814                   196               38140                        NaN
# 75459                   155               19334                  5286.6712
#
# ...

# %%
data=data.reset_index()
data=data.drop("index",1)

# %%
data
# Out:
#                  date_time  site_name  posa_continent  user_location_country  \
# 0      2013-01-07 01:35:53         24               2                      3
# 1      2013-01-07 01:40:20          2               3                     48
# 2      2013-01-07 02:47:27          2               3                     66
# 3      2013-01-07 03:31:11          2               3                    154
# 4      2013-01-07 03:59:19         11               3                    205
# 5      2013-01-07 07:03:23         34               3                    205
# 6      2013-01-07 07:03:41          2               3                     48
# 7      2013-01-07 07:18:00          2               3                     66
# 8      2013-01-07 07:18:10          2               3                     66
# 9      2013-01-07 07:47:27          2               3                     66
# 10     2013-01-07 08:27:34          2               3                     66
# ...

# %%
data = data.drop_duplicates(['date_time'], keep='last')

# %%
data.to_csv('randomTrain.csv')
